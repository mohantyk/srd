# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import global_params as G
plt.rcParams['figure.figsize'] = G.SMALL_FIG

# %%
import numpy as np
from scipy import signal
from scipy.fftpack import fft

np.set_printoptions(precision=4, suppress=True)

# %%
from freq_domain import plotspec
from wavegen import cosine_wave
from utilities import db
from transmitter import pulse_shaped
from carrier_recovery import *

# %% [markdown]
# ## 10.1 Estimation Using FFT

# %%
N = 10000 # num symbols
M = 20 # oversampling factor
Ts = 0.0001 # sampling frequency

fc = 1000 # Carrier frequency
phi = -1  # Phase offset

# %%
duration = Ts*M*N
t, carrier = cosine_wave(fc, duration, Ts, phi)

# %%
symbols = np.random.choice([-3, -1, 1, 3], N) # 4-PAM
waveform = pulse_shaped(symbols, M)
modulated_suppr_carrier = waveform * carrier
modulated_large_carrier = (1 + waveform) * carrier

# %% [markdown]
# ### Large carrier

# %%
plotspec(modulated_large_carrier, Ts);

# %%
freq, phase = estimate_carrier_with_fft(modulated_large_carrier, Ts)
print(f'Estimated carrier freq = {freq}, Actual carrier freq = {fc}')
print(f'Estimated carrier pahse = {phase:.2f}, Actual carrier phase = {phi}')
# Out:
# Estimated carrier freq = 1000.0, Actual carrier freq = 1000
# Estimated carrier pahse = -1.00, Actual carrier phase = -1

# %% [markdown]
# ### Suppressed Carrier

# %%
plotspec(modulated_suppr_carrier, Ts);

# %%
# Above method does not work with suppressed carrier
# Remember that even a 0.01 frequency offset can be catastrophic
freq, phase = estimate_carrier_with_fft(modulated_suppr_carrier, Ts)
print(f'Estimated carrier freq = {freq}, Actual carrier freq = {fc}')
print(f'Estimated carrier pahse = {phase:.2f}, Actual carrier phase = {phi}')
# Out:
# Estimated carrier freq = 927.7, Actual carrier freq = 1000
# Estimated carrier pahse = -0.29, Actual carrier phase = -1

# %%
# Spectrum with a square non-linearity
plotspec(modulated_suppr_carrier**2, Ts);

# %%
# The DC component is the non-zero average of the squared waveform.
# The spike at 500 Hz is because the symbol is generated by a square wave
# with symbol period = Ts * M = 0.002 secs, or freq = 500 Hz
plotspec(waveform**2, Ts);

# %%
squared_signal = modulated_suppr_carrier ** 2 # Use a square non-linearity
# Create bandpass filter at twice the carrier frequency
taps = 500
Fs = 1/Ts
band_edges = [0, 1900, 1950, 2050, 2100, 5000]
damps = [0, 1, 0]
bpf = signal.remez(taps, band_edges, damps, fs=Fs)
w, h = signal.freqz(bpf,1, len(squared_signal), fs=Fs)
preprocessed = signal.lfilter(bpf, 1, squared_signal)
plt.plot(w, db(h));

# %%
# Now use the fft method
freq_2x, phase_2x_with_bpf = estimate_carrier_with_fft(preprocessed, Ts)
freq = freq_2x/2
# Account for BPF phase
idx = np.abs(w - freq_2x).argmin()
bpf_phase = np.angle(h[idx])
phase = (phase_2x_with_bpf - bpf_phase)/2
print(f'Estimated carrier freq = {freq}, Actual carrier freq = {fc}')
print(f'Estimated carrier pahse = {phase:.2f}, Actual carrier phase = {phi}')
# Out:
# Estimated carrier freq = 1000.0, Actual carrier freq = 1000
# Estimated carrier pahse = -1.00, Actual carrier phase = -1

# %% [markdown]
# ## 10.2 Squared Difference Loop

# %%
# Carrier parameters
Ts = 1/10000
duration = 1
fc = 100
phi = 0.8

t, squared_carrier = cosine_wave(2*fc, duration, Ts, 2*phi)

# %%
# Adaptive parameters
mu = 0.001
window_len = 25
f0 = fc # Frequency is supposed to be known perfectly
initial_phase_estimate = 0

theta = np.zeros_like(t)
theta[0] = initial_phase_estimate
avg_filter = np.ones(window_len)/window_len 
buffer = np.zeros_like(avg_filter)

for k, tick in enumerate(t[:-1]):
    deriv = ((squared_carrier[k] - np.cos(4*np.pi*f0*tick + 2*theta[k]))*
            np.sin(4*np.pi*f0*tick + 2*theta[k]))
    buffer = np.roll(buffer, 1)
    buffer[0] = deriv
    theta[k+1] = theta[k] - mu*np.dot(avg_filter, buffer)
    
plt.plot(t, theta);
theta[-5:]
# Out:
# array([0.8, 0.8, 0.8, 0.8, 0.8])

# %%
# Averaging works like a LPF
h, w = signal.freqz(avg_filter, 1, fs=1/Ts)
plt.plot(h, db(w));

# %%
# Error surface for squared difference error
theta = np.arange(-2*np.pi, 2*np.pi, 0.01)
sd_error_surface = (1-np.cos(2*theta - 2*phi))
plt.plot(theta, sd_error_surface);

# %%
# Ex 10.9
theta_suppressed_carrier = pll_sq_diff(preprocessed[:10000], 1000, 0.0001);

plt.plot(theta_suppressed_carrier);
# The algorithm estimated theta + bpf_phase/2. Compensate for the bpf phase
final_phase_est = theta_suppressed_carrier[-1] - bpf_phase/2 
print(f'Estimated carrier phase = {final_phase_est:.2f}, actual phase = -1')
# Out:
# Estimated carrier phase = -1.00, actual phase = -1

# %% [markdown]
# ## 10.3 PLL

# %%
# Carrier parameters
Ts = 1/10000
duration = 1
fc = 1000
phi = -0.8

t, squared_carrier = cosine_wave(2*fc, duration, Ts, 2*phi)

# %%
# Adaptive parameters
mu = 0.003
taps = 100
psi = 0
# Initial estimates
f0 = fc
ph_initial = 0

Fs = 1/Ts
band_edges = np.array([0, 0.01, 0.02, 1])*(Fs/2)
damps = [1, 0]
lpf = signal.remez(taps, band_edges, damps, fs=Fs)

theta = np.zeros_like(squared_carrier)
theta[0] = ph_initial
buffer = np.zeros_like(lpf)
for k, sample in enumerate(squared_carrier[:-1]):
    tick = k*Ts
    deriv = np.sin(4*np.pi*f0*tick + 2*theta[k] + psi)*sample
    buffer = np.roll(buffer, 1)
    buffer[0] = deriv
    theta[k+1] = theta[k] - mu*np.dot(lpf, buffer)

    
plt.plot(t, theta);
theta[-5:]
# Out:
# array([-0.7999, -0.8   , -0.8   , -0.8   , -0.8   ])

# %%
# Ex 10.14
theta_suppressed_carrier = pll(preprocessed[:10000], 1000, 0.0001, psi=bpf_phase);

plt.plot(theta_suppressed_carrier);
final_phase_est = theta_suppressed_carrier[-1]
print(f'Estimated carrier phase = {final_phase_est:.2f}, actual phase = -1')
# Out:
# Estimated carrier phase = -1.00, actual phase = -1

# %% [markdown]
# ## 10.4 Costas Loop

# %%
# No need to preprocess carrier
theta_costas = costas(modulated_suppr_carrier[:10000], 1000, 0.0001, mu=0.003);

plt.plot(theta_costas);
final_phase_est = theta_costas[-1]
print(f'Estimated carrier phase = {final_phase_est:.2f}, actual phase = -1')
# Out:
# Estimated carrier phase = -1.00, actual phase = -1

# %% [markdown]
# ## 10.6.2 Indirect Frequency Estimation

# %%
# Carrier parameters
Ts = 1/10000
duration = 2
fc = 1000
phi = -2

t, squared_carrier = cosine_wave(2*fc, duration, Ts, 2*phi)

# Use dual plls to estimate frequency and phase
f0 = 1007
(freq_est, phase_est), (theta1, theta2), est_sq_carrier = dual_plls(squared_carrier, f0, Ts)
print(f'Freq estimate: {freq_est:.2f}, phase estimate: {phase_est:.2f} (= {phase_est-np.pi:.2f})')
# Out:
# Freq estimate: 1000.00, phase estimate: 1.14 (= -2.00)

# %%
plt.subplot(311); plt.plot(t, theta1)
plt.subplot(312); plt.plot(t, theta2)
plt.subplot(313); plt.plot(t, squared_carrier-est_sq_carrier);

# %%
# Ex 10.36 - Add noise
noise_var = 1
f0 = 1007

noise = np.sqrt(noise_var) * np.random.randn(*squared_carrier.shape)
sig = squared_carrier + noise
(freq_est, phase_est), (theta1, theta2), est_sq_carrier = dual_plls(sig, f0, Ts)
print(f'Freq estimate: {freq_est:.2f}, phase estimate: {phase_est:.2f} (= {phase_est-np.pi:.2f})')
# Out:
# Freq estimate: 1000.02, phase estimate: 1.07 (= -2.07)
